# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\ASUS-PC\Desktop\kc_house_data.csv",sep=",")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# We have 21613 entries and 21 columns. the type mostly used is integer.

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# According to the below instruction, there's no nan value in the dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df1 = df.drop('id',axis=1)
df1 = df1.drop('date',axis=1)
df1 = df1.drop('waterfront',axis=1)
df1 = df1.drop('floors',axis=1)
df1 = df1.drop('grade',axis=1)
df1 = df1.drop('sqft_lot15',axis=1)
df1 = df1.drop('sqft_lot',axis=1)
df1 = df1.drop('condition',axis=1)
df1 = df1.drop('long',axis=1)
df1 = df1.drop('lat',axis=1)
df1 = df1.drop('yr_renovated',axis=1)

def plot_correlation_map( df1):

    corr = df1.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
print (plot_correlation_map( df1 ))
# Out:
# None

# %% [markdown]
# In order to pick the most important features, i've dropped the useless axis and let the ones correlated with the price ( the output). Through this map, sqft_living turns out to be the most correlated feature since its value =0.7 besides
# sqft_above,sqft_living15,view, bathrooms and bedrooms.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
y=df["price"]
x=df[["sqft_living"]]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)
model=LinearRegression() 
model.fit(x_train,y_train)
predicted=model.predict(x_test)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 61758349790.52605
# R squared 0.5107609272631098

# %% [markdown]
# The average squared difference between the estimated values and the actual value is quite high but gives r squared close to 0.5 so half of the output variation (price) can be explained by the model's input.

# %%
x=df[["sqft_living","sqft_above","sqft_living15","bathrooms","view","bedrooms","sqft_basement","yr_built","condition","zipcode"]] 
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)
model=LinearRegression()
model.fit(x_train,y_train)
predicted=model.predict(x_test)
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 45730154972.520935
# R squared 0.6038507441730379

# %% [markdown]
# The r squared improved itself when we added so many features as input. The features used meant to be important for our model.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures 
lg = LinearRegression() 
poly = PolynomialFeatures(degree = 2) 
x_=poly.fit_transform(x)
x_=poly.fit_transform(x)
print("x before transformation: ", x)
print("x after transformation: ", x_)
lg.fit(x_, y)
# Out:
# x before transformation:         sqft_living  sqft_above  sqft_living15  bathrooms  view  bedrooms  \
# 0             1180        1180           1340       1.00     0         3
# 1             2570        2170           1690       2.25     0         3
# 2              770         770           2720       1.00     0         2
# 3             1960        1050           1360       3.00     0         4
# 4             1680        1680           1800       2.00     0         3
# ...            ...         ...            ...        ...   ...       ...
# 21608         1530        1530           1530       2.50     0         3
# 21609         2310        2310           1830       2.50     0         4
# 21610         1020        1020           1020       0.75     0         2
# 21611         1600        1600           1410       2.50     0         3
# 21612         1020        1020           1020       0.75     0         2
#
#        sqft_basement  yr_built  condition  zipcode
# ...

# %%
x_train_fit = poly.fit_transform(x_train)
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)
print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  36813351487.698326
# R squared:  0.6810948529452546

# %% [markdown]
# The polynomial regression gives a r squared quite close to the multi regression model but on the other hand, it remains a beter way to predict the housse's price
