# %%
import pandas as pd 
df=pd.read_csv(r"C:\Users\Ameur\Downloads\titanic-passengers.csv",sep=';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df["Embarked"].fillna('S',inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.dropna(axis=1,inplace=True)
import sklearn
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Embarked']=encoder.fit_transform (df['Embarked'])
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# ...

# %% [markdown]
# from sklearn.model_selection import train_test_split
# from sklearn import tree
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.metrics import accuracy_score
#
# x=df.drop(["Survived", "Name","Ticket"], axis=1)
# y= df["Survived"]
#
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
# dtree= tree.DecisionTreeClassifier()
# dtree.fit(x_train, y_train)
# y_pred=dtree.predict(x_test)
# print("score:{}".format(accuracy_score(y_test, y_pred)))

# %%
import matplotlib.pyplot as plt 
from sklearn.tree import plot_tree
plt.figure(figsize = (30,20))
plot_tree(dtree, filled = True, feature_names = x.columns, proportion = True)
# Out:
# [Text(618.2761948529412, 1057.0, 'Sex <= 0.5\ngini = 0.469\nsamples = 100.0%\nvalue = [0.624, 0.376]'),
#  Text(276.9485294117647, 996.6, 'Pclass <= 2.5\ngini = 0.39\nsamples = 35.4%\nvalue = [0.266, 0.734]'),
#  Text(105.76470588235294, 936.2, 'Age <= 2.5\ngini = 0.1\nsamples = 18.7%\nvalue = [0.053, 0.947]'),
#  Text(91.17647058823529, 875.8, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(120.35294117647058, 875.8, 'Fare <= 26.125\ngini = 0.087\nsamples = 18.5%\nvalue = [0.045, 0.955]'),
#  Text(80.23529411764706, 815.4000000000001, 'PassengerId <= 48.0\ngini = 0.198\nsamples = 6.3%\nvalue = [0.111, 0.889]'),
#  Text(65.6470588235294, 755.0, 'gini = 0.0\nsamples = 0.1%\nvalue = [1.0, 0.0]'),
#  Text(94.82352941176471, 755.0, 'Age <= 55.5\ngini = 0.165\nsamples = 6.2%\nvalue = [0.091, 0.909]'),
#  Text(80.23529411764706, 694.6, 'SibSp <= 0.5\ngini = 0.13\nsamples = 6.0%\nvalue = [0.07, 0.93]'),
# ...

# %%
x=df.drop(["Survived", "Name","Ticket"], axis=1)
y= df["Survived"]

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20)
decision_tree = DecisionTreeClassifier(max_depth=2,max_leaf_nodes=5,min_samples_leaf=1)
decision_tree.fit(x_train, y_train) 
y_pred=decision_tree.predict(x_test)
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7374301675977654

# %%
import matplotlib.pyplot as plt 
from sklearn.tree import plot_tree
plt.figure(figsize = (30,20))
plot_tree(decision_tree, filled = True, feature_names = x.columns, proportion = True)
# Out:
# [Text(837.0, 906.0, 'Sex <= 0.5\ngini = 0.475\nsamples = 100.0%\nvalue = [0.612, 0.388]'),
#  Text(418.5, 543.6, 'Pclass <= 2.5\ngini = 0.387\nsamples = 35.8%\nvalue = [0.263, 0.737]'),
#  Text(209.25, 181.19999999999993, 'gini = 0.111\nsamples = 19.0%\nvalue = [0.059, 0.941]'),
#  Text(627.75, 181.19999999999993, 'gini = 0.5\nsamples = 16.9%\nvalue = [0.492, 0.508]'),
#  Text(1255.5, 543.6, 'Age <= 1.5\ngini = 0.311\nsamples = 64.2%\nvalue = [0.807, 0.193]'),
#  Text(1046.25, 181.19999999999993, 'gini = 0.0\nsamples = 1.0%\nvalue = [0.0, 1.0]'),
#  Text(1464.75, 181.19999999999993, 'gini = 0.295\nsamples = 63.2%\nvalue = [0.82, 0.18]')]

# %%
from sklearn.ensemble import RandomForestClassifier


clf=RandomForestClassifier(n_estimators=200)
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8435754189944135

# %%
clf=RandomForestClassifier(n_estimators=1000)
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)  
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8379888268156425

# %% [markdown]
# The nomber of estimator isn't related to the accuracy. there's no dependency between the two of them since when the n_estimators=200, the accuracy is equivalent to 84% and when we increase the n_estimators to 1000, the accuracy decreased to 83%.
